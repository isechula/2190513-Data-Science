# %%
import pandas

# %%
#if you are a normal human being do this

df = pandas.read_csv('./scores.csv')
query = input()

match query:
    case "Q1":
        print(df.shape)
    case "Q2":
        print(df["score"].max())
    case "Q3":
        print(len(df.loc[df['score'] >= 80, ['score']]))
    case _:
        print("No Output")
# Out:
# No Output

# %%
#since the ones grading assignment aren't, do this

Q1 = lambda df: df.shape
Q2 = lambda df: df["score"].max()
Q3 = lambda df: len(df.loc[df['score'] >= 80, ['score']])
Q4 = lambda df: "No Output"
